# %%
from string import ascii_letters
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import math

# %%
df = pd.read_csv('meteonogal.csv', sep=',', engine='python')
df.head()
# Out:
#        DATE   TIME  Unnamed: 2  Unnamed: 3  u_Avg      v_Avg        w_Avg  \
# 0        TS    NaN         NaN         NaN    m/s        m/s          m/s
# 1  01-01-09  00:10         1.0         NaN  1.215      0.506       -0.044
# 2  01-01-09  00:20         1.0         NaN  0.892      0.588       -0.072
# 3  01-01-09  00:30         1.0         NaN  1.227  0.6850001  -0.06900001
# 4  01-01-09  00:40         1.0         NaN  1.135  0.7410001       -0.093
#
#    t_Avg kh20_Avg net_rad_Avg     ...     Unnamed: 26 Unnamed: 27 Unnamed: 28  \
# 0   degC       mV        w/m2     ...             NaN         NaN         NaN
# 1  10.95    1.159      -176.5     ...             NaN         NaN         NaN
# 2  10.81    1.159      -176.6     ...             NaN         NaN         NaN
# 3  10.34    1.224      -175.5     ...             NaN         NaN         NaN
# 4    9.8    1.258      -182.7     ...             NaN         NaN         NaN
#
# ...

# %%
df.dtypes
# Out:
# DATE            object
# TIME            object
# Unnamed: 2     float64
# Unnamed: 3     float64
# u_Avg           object
# v_Avg           object
# w_Avg           object
# t_Avg           object
# kh20_Avg        object
# net_rad_Avg     object
# shf1_Avg        object
# shf2_Avg        object
# vv_Avg          object
# airT_Avg        object
# rh_Avg         float64
# e_sat_Avg       object
# e_Avg           object
# h2o_hmp_Avg     object
# Unnamed: 18    float64
# Unnamed: 19     object
# Unnamed: 20     object
# Unnamed: 21    float64
# Unnamed: 22     object
# Unnamed: 23     object
# Unnamed: 24     object
# Unnamed: 25     object
# Unnamed: 26     object
# Unnamed: 27     object
# Unnamed: 28     object
# Unnamed: 29     object
# Unnamed: 30     object
# Unnamed: 31     object
# Unnamed: 32     object
# Unnamed: 33     object
# Unnamed: 34     object
# Unnamed: 35     object
# dtype: object

# %%
# para eliminar columnas sin información, se buscó la manera
# de eliminar aquellas que no estén nombradas 'unnamed'
df = df.drop(df.columns[df.columns.str.contains('unnamed:',case = False)],axis = 1)
df.head()
# Out:
#        DATE   TIME  u_Avg      v_Avg        w_Avg  t_Avg kh20_Avg net_rad_Avg  \
# 0        TS    NaN    m/s        m/s          m/s   degC       mV        w/m2
# 1  01-01-09  00:10  1.215      0.506       -0.044  10.95    1.159      -176.5
# 2  01-01-09  00:20  0.892      0.588       -0.072  10.81    1.159      -176.6
# 3  01-01-09  00:30  1.227  0.6850001  -0.06900001  10.34    1.224      -175.5
# 4  01-01-09  00:40  1.135  0.7410001       -0.093    9.8    1.258      -182.7
#
#   shf1_Avg shf2_Avg vv_Avg  airT_Avg  rh_Avg e_sat_Avg  e_Avg h2o_hmp_Avg
# 0     w/m2     w/m2    m/s      degC     NaN       kPa    kPa        g/m3
# 1    23.58   -26.72  1.327       9.4   0.899     1.178  1.059        8.12
# 2    23.73   -26.76  1.079      9.24   0.896     1.166  1.045        8.02
# 3    23.61   -26.46  1.421  9.059999   0.896     1.152  1.032    7.926001
# 4    23.41   -26.46  1.384  9.059999   0.874     1.152  1.008       7.737

# %%
df.dtypes
# Out:
# DATE            object
# TIME            object
# u_Avg           object
# v_Avg           object
# w_Avg           object
# t_Avg           object
# kh20_Avg        object
# net_rad_Avg     object
# shf1_Avg        object
# shf2_Avg        object
# vv_Avg          object
# airT_Avg        object
# rh_Avg         float64
# e_sat_Avg       object
# e_Avg           object
# h2o_hmp_Avg     object
# dtype: object

# %%
df = df.drop([0], axis=0)
df.head(3)
# Out:
#        DATE   TIME  u_Avg      v_Avg        w_Avg  t_Avg kh20_Avg net_rad_Avg  \
# 1  01-01-09  00:10  1.215      0.506       -0.044  10.95    1.159      -176.5
# 2  01-01-09  00:20  0.892      0.588       -0.072  10.81    1.159      -176.6
# 3  01-01-09  00:30  1.227  0.6850001  -0.06900001  10.34    1.224      -175.5
#
#   shf1_Avg shf2_Avg vv_Avg  airT_Avg  rh_Avg e_sat_Avg  e_Avg h2o_hmp_Avg
# 1    23.58   -26.72  1.327       9.4   0.899     1.178  1.059        8.12
# 2    23.73   -26.76  1.079      9.24   0.896     1.166  1.045        8.02
# 3    23.61   -26.46  1.421  9.059999   0.896     1.152  1.032    7.926001

# %%
df.dtypes
# Out:
# DATE            object
# TIME            object
# u_Avg           object
# v_Avg           object
# w_Avg           object
# t_Avg           object
# kh20_Avg        object
# net_rad_Avg     object
# shf1_Avg        object
# shf2_Avg        object
# vv_Avg          object
# airT_Avg        object
# rh_Avg         float64
# e_sat_Avg       object
# e_Avg           object
# h2o_hmp_Avg     object
# dtype: object

# %%
df[df.columns[2:16]] = df[df.columns[2:16]].astype(float)
df.dtypes
# Out:
# DATE            object
# TIME            object
# u_Avg          float64
# v_Avg          float64
# w_Avg          float64
# t_Avg          float64
# kh20_Avg       float64
# net_rad_Avg    float64
# shf1_Avg       float64
# shf2_Avg       float64
# vv_Avg         float64
# airT_Avg       float64
# rh_Avg         float64
# e_sat_Avg      float64
# e_Avg          float64
# h2o_hmp_Avg    float64
# dtype: object

# %%
corr = df.corr()
corr
# Out:
#                 u_Avg     v_Avg     w_Avg     t_Avg  kh20_Avg  net_rad_Avg  \
# u_Avg        1.000000  0.241773  0.028537  0.058863 -0.047981    -0.093187
# v_Avg        0.241773  1.000000  0.016387  0.019921  0.153061    -0.116671
# w_Avg        0.028537  0.016387  1.000000  0.667294  0.121010     0.044286
# t_Avg        0.058863  0.019921  0.667294  1.000000 -0.002184     0.064174
# kh20_Avg    -0.047981  0.153061  0.121010 -0.002184  1.000000    -0.157635
# net_rad_Avg -0.093187 -0.116671  0.044286  0.064174 -0.157635     1.000000
# shf1_Avg     0.089411  0.029321 -0.079466 -0.094414 -0.005268    -0.206065
# shf2_Avg     0.003093 -0.053957 -0.011563 -0.008491 -0.058466    -0.027180
# vv_Avg      -0.138616 -0.075175  0.923685  0.593997  0.149991     0.156017
# airT_Avg    -0.363807 -0.341920 -0.374504 -0.288852 -0.116329     0.326684
# rh_Avg       0.326205  0.099303  0.760058  0.433942  0.031765    -0.254705
# ...

# %%
#Utilizando Seaborn

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
# utilizando matplotlib
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns)

# %%
#Utilizando Matplotlib.

fig, matriz = plt.subplots()                    

#Establecemos el tamaño de los ejes.
matriz.set_xticks(np.arange(len(corr)))      
matriz.set_yticks(np.arange(len(corr)))

#Agregamos los nombres de cada variable en los ejes.
matriz.set_xticklabels(corr)                 
matriz.set_yticklabels(corr.columns[::-1])

#Rotamos 90° las etiquetas en el eje x
plt.setp(matriz.get_xticklabels(), rotation=80, ha="right",rotation_mode="anchor")

#Graficamos las correlaciones
plt.imshow(corr,cmap='viridis', interpolation='nearest')


matriz.set_title("Matplotlib")   
plt.show()

# %%
corr = df.corr()
corr
# Out:
#                 u_Avg     v_Avg     w_Avg     t_Avg  kh20_Avg  net_rad_Avg  \
# u_Avg        1.000000  0.241773  0.028537  0.058863 -0.047981    -0.093187
# v_Avg        0.241773  1.000000  0.016387  0.019921  0.153061    -0.116671
# w_Avg        0.028537  0.016387  1.000000  0.667294  0.121010     0.044286
# t_Avg        0.058863  0.019921  0.667294  1.000000 -0.002184     0.064174
# kh20_Avg    -0.047981  0.153061  0.121010 -0.002184  1.000000    -0.157635
# net_rad_Avg -0.093187 -0.116671  0.044286  0.064174 -0.157635     1.000000
# shf1_Avg     0.089411  0.029321 -0.079466 -0.094414 -0.005268    -0.206065
# shf2_Avg     0.003093 -0.053957 -0.011563 -0.008491 -0.058466    -0.027180
# vv_Avg      -0.138616 -0.075175  0.923685  0.593997  0.149991     0.156017
# airT_Avg    -0.363807 -0.341920 -0.374504 -0.288852 -0.116329     0.326684
# rh_Avg       0.326205  0.099303  0.760058  0.433942  0.031765    -0.254705
# ...

# %%
# Se identifican aquellas correlaciones mayores a 0.6 
# Las que se obtuvieron fueron:
# 
# w_Avg y t_Avg con corr = 0.667294
# w_Avg y vv_Avg con corr = 0.923685
# w_Avg y rh_Avg con corr = 0.760058
# w_Avg y e_Avg con corr = 0.641772
# vv_Avg y rh_Avg con corr = 0.624201
# airT_Avg y e_sat_Avg con corr = 0.963527
# rh_Avg y e_Avg con corr = 0.722503
# e_Avg y h2o_hmp_Avg con corr = 0.999154

# %%
corr1 = sns.scatterplot(x=df['w_Avg'],y=df['t_Avg'])

# %%
corr2 = sns.scatterplot(x=df['w_Avg'],y=df['vv_Avg'])

# %%
corr3 = sns.scatterplot(x=df['w_Avg'],y=df['rh_Avg'])

# %%
corr4 = sns.scatterplot(x=df['w_Avg'],y=df['e_Avg'])

# %%
corr5 = sns.scatterplot(x=df['vv_Avg'],y=df['rh_Avg'])

# %%
corr6 = sns.scatterplot(x=df['airT_Avg'],y=df['e_sat_Avg'])

# %%
corr7 = sns.scatterplot(x=df['rh_Avg'],y=df['e_Avg'])

# %%
corr8 = sns.scatterplot(x=df['e_Avg'],y=df['h2o_hmp_Avg'])
